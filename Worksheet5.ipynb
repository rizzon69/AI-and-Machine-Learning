# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

zip_file_path = "/content/drive/MyDrive/Artificial Intelligence and Machine Learning/Week 5/FruitinAmazon.zip"
extract_path = "/content/"

# Unzip the file silently (-q) to the specified extraction path (-d)
# !unzip -q "{zip_file_path}" -d "{extract_path}"

print(f"Successfully extracted '{zip_file_path}' to '{extract_path}'.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Successfully extracted '/content/drive/MyDrive/Artificial Intelligence and Machine Learning/Week 5/FruitinAmazon.zip' to '/content/'.

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

train_data_path = "/content/FruitinAmazon/train"
test_data_path = "/content/FruitinAmazon/test"

class_names = sorted([d for d in os.listdir(train_data_path) if os.path.isdir(os.path.join(train_data_path, d))])

print(class_names)

selected_images_paths = []
selected_class_names = []

for class_name in class_names:
    class_dir = "/content/FruitinAmazon/train/" + class_name

    image_files = [f for f in os.listdir(class_dir)]

    if image_files:
        random_image_name = random.choice(image_files)
        selected_images_paths.append(os.path.join(class_dir, random_image_name))
        selected_class_names.append(class_name)
    else:
        print(f"Warning: No image files found in class directory: {class_dir}")

num_images = len(selected_images_paths)
num_rows = 2
num_cols = (num_images + num_rows - 1) // num_rows
plt.figure(figsize=(num_cols * 3, num_rows * 3))

for i, img_path in enumerate(selected_images_paths):
    try:
        img = Image.open(img_path)
        plt.subplot(num_rows, num_cols, i + 1)
        plt.imshow(img)
        plt.title(selected_class_names[i])
        plt.axis("off")
    except Exception as e:
        print(f"Error loading or displaying image {img_path}: {e}")

plt.tight_layout()
plt.show()
# Out:
# ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ### What did you observe?
#
# - I found that each fruit has multiple images in its respective folder. And all the images of the fruits are from different angles, lighting conditions, orientations etc.

# %%
corrupted_images = []

for class_name in os.listdir(train_data_path):
    class_dir = os.path.join(train_data_path, class_name)

    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)

            if os.path.isfile(image_path):
                try:
                    img = Image.open(image_path)
                    img.verify()
                except (IOError, SyntaxError) as e:
                    print(f"Removed corrupted image: {image_path}")
                    corrupted_images.append(image_path)
                    os.remove(image_path)
                except Exception as e:
                    print(f"An unexpected error occurred with {image_path}: {e}")
                    corrupted_images.append(image_path)

if not corrupted_images:
    print("No Corrupted Images Found.")
# Out:
# No Corrupted Images Found.

# %%
img_height = 128
img_width = 128
batch_size = 32

validation_split = 0.2

rescale = tf.keras.layers.Rescaling(1./255)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_data_path,
  labels="inferred",
  label_mode="int",
  image_size=(img_height, img_width),
  interpolation="nearest",
  batch_size=batch_size,
  shuffle=True,
  validation_split=validation_split,
  subset="training",
  seed=123
)

train_ds = train_ds.map(lambda x, y: (rescale(x), y))

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_data_path,
  labels="inferred",
  label_mode="int",
  image_size=(img_height, img_width),
  interpolation="nearest",
  batch_size=batch_size,
  shuffle=False,
  validation_split=validation_split,
  subset="validation",
  seed=123
)

val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_data_path,
  labels = 'inferred',
  label_mode = 'int',
  image_size = (img_height, img_width),
  interpolation = 'nearest',
  batch_size = batch_size,
  shuffle = False,
  seed = 123
)
test_ds = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 30 files belonging to 6 classes.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

num_classes = len(class_names)

model = keras.Sequential([
  layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
  layers.MaxPooling2D((2, 2)),
  layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
  layers.MaxPooling2D((2, 2)),
  layers.Flatten(),
  layers.Dense(64, activation='relu'),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

checkpoint_filepath = 'best_model.weights.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

history = model.fit(train_ds,validation_data=val_ds,epochs=250, batch_size=16, callbacks=[model_checkpoint_callback, early_stopping_callback])

loss, accuracy = model.evaluate(val_ds)
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")

for images, labels in val_ds.take(1):
    predictions = model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)
    print("\nSample Predictions:")
    print("Predicted labels:", [class_names[p] for p in predicted_labels[:5]])
    print("Actual labels: ", [class_names[l] for l in labels.numpy()[:5]])
# Out:
# Epoch 1/250
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 0.1528 - loss: 2.0278 - val_accuracy: 0.3889 - val_loss: 1.5073
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - accuracy: 0.1806 - loss: 1.9015 - val_accuracy: 0.1667 - val_loss: 1.6737
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 0.1806 - loss: 1.7212 - val_accuracy: 0.1667 - val_loss: 1.9048
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 437ms/step - accuracy: 0.4583 - loss: 1.6395 - val_accuracy: 0.0556 - val_loss: 1.8225
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - accuracy: 0.4861 - loss: 1.4797 - val_accuracy: 0.5556 - val_loss: 1.3989
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 336ms/step - accuracy: 0.5694 - loss: 1.2361 - val_accuracy: 0.6667 - val_loss: 1.1701
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.7361 - loss: 0.9311 - val_accuracy: 0.5000 - val_loss: 1.2761
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.7917 - loss: 0.6974 - val_accuracy: 0.5000 - val_loss: 1.1329
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.8611 - loss: 0.5251 - val_accuracy: 0.7778 - val_loss: 0.7468
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 0.9167 - loss: 0.3743 - val_accuracy: 0.6111 - val_loss: 0.8482
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.8889 - loss: 0.2956 - val_accuracy: 0.7222 - val_loss: 0.5218
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.8750 - loss: 0.3257 - val_accuracy: 0.8889 - val_loss: 0.4758
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - accuracy: 0.9861 - loss: 0.1281 - val_accuracy: 0.7778 - val_loss: 0.8329
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.9306 - loss: 0.1457 - val_accuracy: 0.6111 - val_loss: 0.9057
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 426ms/step - accuracy: 0.9722 - loss: 0.0759 - val_accuracy: 0.8889 - val_loss: 0.4644
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 0.8889 - val_loss: 0.4878
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - accuracy: 1.0000 - loss: 0.0492 - val_accuracy: 0.8333 - val_loss: 0.5326
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.7778 - val_loss: 0.6214
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.7778 - val_loss: 0.5838
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8889 - val_loss: 0.5131
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.8889 - val_loss: 0.5133
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 540ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8889 - val_loss: 0.5268
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 563ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8333 - val_loss: 0.5391
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 452ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 0.5445
# Epoch 25/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 0.5311
# Epoch 26/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8333 - val_loss: 0.5111
# Epoch 27/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8333 - val_loss: 0.4961
# Epoch 28/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8333 - val_loss: 0.4887
# Epoch 29/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 312ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8889 - val_loss: 0.4917
# Epoch 30/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8889 - val_loss: 0.4999
# Epoch 31/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8889 - val_loss: 0.5037
# Epoch 32/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8889 - val_loss: 0.5072
# Epoch 33/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8333 - val_loss: 0.5069
# Epoch 34/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 1.0000 - loss: 9.8286e-04 - val_accuracy: 0.8333 - val_loss: 0.5031
# Epoch 35/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 1.0000 - loss: 9.0845e-04 - val_accuracy: 0.8333 - val_loss: 0.4983
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8889 - loss: 0.4644
# Validation Loss: 0.4644
# Validation Accuracy: 0.8889
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#
# Sample Predictions:
# Predicted labels: ['pupunha', 'tucuma', 'pupunha', 'tucuma', 'tucuma']
# Actual labels:  ['pupunha', 'pupunha', 'pupunha', 'tucuma', 'tucuma']

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].plot(history.history['accuracy'], label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[1].plot(history.history['loss'], label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
plt.tight_layout()
plt.show()

# %%
loss, accuracy = model.evaluate(val_ds)
print(f"Validation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8889 - loss: 0.4644
# Validation Loss: 0.4644
# Validation Accuracy: 0.8889

# %%
model_save_path = 'fruit_classifier_model.h5'
model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to fruit_classifier_model.h5

# %%
loaded_model = keras.models.load_model('fruit_classifier_model.h5')
print("Model loaded successfully!")

loaded_loss, loaded_accuracy = loaded_model.evaluate(val_ds)
print(f"\nLoaded Model Validation Loss: {loaded_loss:.4f}")
print(f"Loaded Model Validation Accuracy: {loaded_accuracy:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8889 - loss: 0.4644
#
# Loaded Model Validation Loss: 0.4644
# Loaded Model Validation Accuracy: 0.8889

# %%
from sklearn.metrics import classification_report

y_true = []
y_pred_probs = []

for images, labels in test_ds:
  preds = loaded_model.predict(images, verbose=0)
  y_pred_probs.extend(preds)
  y_true.extend(labels.numpy())

y_true = np.array(y_true)
y_pred = np.argmax(np.array(y_pred_probs), axis=1)
print('Predicted labels:', [class_names[i] for i in y_pred[:5]])
print('Actual labels :', [class_names[i] for i in y_true[:5]])

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Predicted labels: ['acai', 'acai', 'acai', 'acai', 'acai']
# Actual labels : ['acai', 'acai', 'acai', 'acai', 'acai']
#               precision    recall  f1-score   support
#
#         acai       0.71      1.00      0.83         5
#      cupuacu       0.67      0.80      0.73         5
#     graviola       0.71      1.00      0.83         5
#      guarana       0.67      0.40      0.50         5
#      pupunha       0.50      0.20      0.29         5
#       tucuma       0.20      0.20      0.20         5
#
#     accuracy                           0.60        30
#    macro avg       0.58      0.60      0.56        30
# weighted avg       0.58      0.60      0.56        30

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=class_names, yticklabels=class_names)

plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()
